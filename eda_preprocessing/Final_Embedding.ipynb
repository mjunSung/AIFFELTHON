# %%
import os
import pickle
import pandas as pd
import numpy as np
import time
import json
import pickle
import requests
import tiktoken
import getpass
import logging
from tqdm import tqdm
from tqdm.notebook import tqdm
from dotenv import load_dotenv
from langchain.docstore.document import Document
from langchain_community.embeddings import ClovaXEmbeddings
from langchain_community.chat_models import ChatClovaX
from langchain.vectorstores import Milvus
from langchain.chains import RetrievalQA, LLMChain
from langchain.prompts import PromptTemplate
from langchain.text_splitter import RecursiveCharacterTextSplitter

# %%
# 로깅 설정
logging.basicConfig(
    level=logging.INFO, format="%(asctime)s - %(levelname)s - %(message)s"
)
logger = logging.getLogger(__name__)

# %%
# 환경설정
load_dotenv(dotenv_path=r"")
api_key = os.getenv("NCP_CLOVASTUDIO_API_KEY")
api_url = os.getenv("NCP_CLOVASTUDIO_API_URL", "https://clovastudio.stream.ntruss.com/")
milvus_host = os.getenv("MILVUS_HOST", "localhost")
milvus_port = os.getenv("MILVUS_PORT", "19530")
os.environ["NCP_CLOVASTUDIO_API_KEY"] = api_key
os.environ["NCP_CLOVASTUDIO_API_URL"] = api_url

try:
    ncp_embeddings = ClovaXEmbeddings(model="bge-m3")
    llm_clova = ChatClovaX(model="HCX-003", max_tokens=2048)
    logger.info("ClovaX Embeddings 및 Chat 모델 초기화 완료")
except Exception as e:
    logger.error(f"ClovaX 모델 초기화 실패: {e}")
    raise
# Out:
# 2025-04-03 15:00:40,897 - INFO - ClovaX Embeddings 및 Chat 모델 초기화 완료

# %%
# 단순 텍스트 스플리터
def split_text(text, chunk_size=2000, overlap=250):
    if not text or pd.isnull(text):
        return [""]
    chunks = []
    for i in range(0, len(text), chunk_size - overlap):
        chunks.append(text[i : i + chunk_size])
    return chunks


# RecursiveCharacterTextSplitter library recursive splitter
recursive_splitter = RecursiveCharacterTextSplitter(
    chunk_size=2000, chunk_overlap=250, separators=["\n\n", "\n", "."]
)

# %%
df = pd.read_csv(
    r""
)

# %%
df["발행일"]

# %%
# 메타데이터 및 벡터 문서 컬럼 설정
metadata_columns = [
    "ISBN",
    "페이지",
    "가격",
    "제목",
    "부제",
    "저자",
    "분류",
    "목차",
    "발행자",
    "표지",
]
vector_doc_columns = [
    "제목",
    "부제",
    "분류",
    "저자",
    "저자소개",
    "책소개",
    "출판사리뷰",
    "추천사",
    "목차",
]

# %%
# 청크 생성
RAG_DB = []
for index, row in df.iterrows():
    metadata = {col: row.get(col, None) for col in metadata_columns}

    # 목차 : 단순 스플리터 적용
    toc_text = row.get("목차", "")
    if pd.isnull(toc_text):
        toc_text = ""
    toc_chunks = split_text(toc_text, chunk_size=2000, overlap=250)

    # non-목차 : 목차 컬럼 제외한 나머지 컬럼은 하나의 텍스트로 연결 후 recursive splitter 적용
    non_toc_text = ""
    for col in vector_doc_columns:
        if col == "목차":
            continue
        value = row.get(col, "")
        if pd.isnull(value):
            value = ""
        non_toc_text += f"{col}: {value}\n"
    recursive_chunks = recursive_splitter.split_text(non_toc_text)

    # 다른 방식의 두 청크들에 동일 Document로 추가
    for chunk in recursive_chunks:
        RAG_DB.append({"text": chunk, "metadata": metadata})
    for chunk in toc_chunks:
        RAG_DB.append({"text": f"목차: {chunk}", "metadata": metadata})

documents = [
    Document(page_content=entry["text"], metadata=entry["metadata"]) for entry in RAG_DB
]

# %%
# 청크 개수
total_chunks = len(documents)
logger.info(f"총 청크 개수: {total_chunks}")
# Out:
# 2025-04-04 11:30:27,464 - INFO - 총 청크 개수: 116218

# %%
# 1. HTTP 로그X
logging.getLogger("httpx").setLevel(logging.WARNING)
logging.getLogger("urllib3").setLevel(logging.WARNING)

# %%
# batch size
batch_size = 5000
total_chunks = len(documents)
batch_dir = r"C:\Kill_the_RAG\Project\Aiffel_final_project\Code\Data\final_embedding"
os.makedirs(batch_dir, exist_ok=True)

# %%
# 배치 임베딩 파일 불러오기
progress = {}
for batch_idx in range((total_chunks // batch_size) + 1):
    file_path = os.path.join(batch_dir, f"embedding_progress_{batch_idx}.pkl")
    if os.path.exists(file_path):
        with open(file_path, "rb") as f:
            try:
                loaded = pickle.load(f)
                progress.update(loaded)
            except Exception as e:
                print(f"[경고] {file_path} 로드 실패: {e}")

processed_count = len(progress)
remaining_count = total_chunks - processed_count
print(f"[INFO] 이미 처리된 청크: {processed_count}, 남은 청크: {remaining_count}")
# Out:
# [INFO] 이미 처리된 청크: 0, 남은 청크: 116218

# %%
# 임베딩
for i, doc in enumerate(tqdm(documents, desc="임베딩 처리 중", unit="doc")):
    if i in progress:
        continue

    text_chunk = doc.page_content
    embedding = None

    while embedding is None:
        try:
            embedding = ncp_embeddings.embed_query(text_chunk)
        except Exception as e:
            print(f"[에러] 문서 {i} 임베딩 실패: {e}")
            if "429" in str(e):
                print("[경고] 요청 제한 초과. 10초 대기 후 재시도")
                time.sleep(8)
                continue
            embedding = None

    progress[i] = {"text": text_chunk, "embedding": embedding, "metadata": doc.metadata}

    # 배치 단위 저장
    if len(progress) % batch_size == 0:
        batch_idx = len(progress) // batch_size - 1
        temp_path = os.path.join(batch_dir, f"embedding_progress_{batch_idx}.pkl.temp")
        final_path = os.path.join(batch_dir, f"embedding_progress_{batch_idx}.pkl")
        with open(temp_path, "wb") as f:
            pickle.dump(
                {k: v for k, v in progress.items() if k // batch_size == batch_idx}, f
            )
        os.replace(temp_path, final_path)

    time.sleep(0.8)
# Out:
# 임베딩 처리 중:   0%|          | 0/116218 [00:00<?, ?doc/s]
# [에러] 문서 60 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 120 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 180 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 240 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 300 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 360 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 420 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 480 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 540 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 596 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 652 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 652 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 712 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 772 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 832 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 892 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 952 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 1012 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 1072 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 1132 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 1192 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 1252 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 1312 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 1372 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 1432 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 1492 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 1552 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 1611 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 1671 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 1727 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 1727 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 1787 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 1847 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 1907 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 1963 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 1963 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 2021 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 2076 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 2076 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 2136 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 2196 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 2256 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 2316 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 2376 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 2436 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 2496 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 2556 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 2616 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 2676 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 2736 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 2792 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 2792 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 2847 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 2847 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 2907 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 2967 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 3027 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 3087 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 3147 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 3207 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 3267 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 3327 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 3387 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 3447 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 3507 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 3567 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 3627 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 3687 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 3747 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 3807 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 3864 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 3924 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 3984 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 4044 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 4103 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 4159 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 4219 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 4275 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 4335 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 4395 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 4455 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 4515 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 4575 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 4635 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 4695 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 4751 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 4751 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 4811 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 4871 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 4931 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 4991 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 5051 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 5111 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 5171 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 5231 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 5291 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 5347 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 5347 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 5407 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 5467 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 5527 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 5587 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 5647 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 5707 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 5767 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 5827 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 5887 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 5942 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 5942 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 6002 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 6062 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 6122 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 6182 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 6242 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 6295 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 6295 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 6350 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 6350 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 6410 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 6466 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 6466 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 6523 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 6523 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 6578 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 6578 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 6634 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 6634 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 6694 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 6750 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 6750 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 6810 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 6869 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 6924 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 6924 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 6984 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 7044 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 7104 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 7164 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 7224 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 7284 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 7344 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 7400 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 7400 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 7460 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 7520 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 7580 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 7640 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 7700 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 7760 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 7820 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 7880 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 7940 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 8000 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 8060 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 8120 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 8180 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 8240 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 8300 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 8360 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 8420 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 8480 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 8540 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 8600 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 8660 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 8720 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 8780 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 8840 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 8900 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 8960 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 9020 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 9080 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 9140 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 9200 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 9260 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 9320 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 9380 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 9440 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 9500 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 9560 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 9620 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 9680 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 9740 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 9800 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 9860 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 9920 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 9975 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 9975 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 10031 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 10091 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 10151 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 10211 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 10271 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 10331 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 10391 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 10451 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 10511 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# ...
# [에러] 문서 112374 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 112434 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 112494 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 112554 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 112614 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 112674 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 112734 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 112794 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 112854 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 112914 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 112974 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 113034 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 113094 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 113154 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 113214 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 113274 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 113334 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 113394 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 113454 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 113514 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 113574 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 113634 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 113694 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 113754 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 113814 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 113874 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 113934 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 113994 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 114054 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 114114 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 114174 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 114234 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 114294 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 114354 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 114414 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 114474 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 114534 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 114594 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 114654 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 114714 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 114774 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 114834 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 114894 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 114954 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 115014 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 115074 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 115134 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 115194 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 115254 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 115314 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 115374 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 115434 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 115494 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 115554 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 115614 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 115674 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 115734 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 115794 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 115854 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 115914 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 115974 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 116034 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 116094 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 116154 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도
# [에러] 문서 116214 임베딩 실패: Error response 429 while fetching https://clovastudio.stream.ntruss.com/testapp/v1/api-tools/embedding/v2: {"status":{"code":"42901","message":"Too many requests - rate exceeded"},"result":null}
# [경고] 요청 제한 초과. 10초 대기 후 재시도

# %%
# 마지막 배치
last_batch_idx = len(progress) // batch_size
temp_path = os.path.join(batch_dir, f"embedding_progress_{last_batch_idx}.pkl.temp")
final_path = os.path.join(batch_dir, f"embedding_progress_{last_batch_idx}.pkl")
with open(temp_path, "wb") as f:
    pickle.dump(
        {k: v for k, v in progress.items() if k // batch_size == last_batch_idx}, f
    )
os.replace(temp_path, final_path)

print(f"[INFO] 총 처리된 청크: {len(progress)} / {total_chunks}")
# Out:
# [INFO] 총 처리된 청크: 116218 / 116218

# %%
batch_dir = r"C:\Kill_the_RAG\Project\Aiffel_final_project\Code\Data\final_embedding"
final_output_path = os.path.join(batch_dir, "final_embedding.pkl")

merged_progress = {}

# 병합 0~23 batch
for batch_idx in range(24):
    file_path = os.path.join(batch_dir, f"embedding_progress_{batch_idx}.pkl")
    if os.path.exists(file_path):
        with open(file_path, "rb") as f:
            try:
                data = pickle.load(f)
                merged_progress.update(data)
            except Exception as e:
                print(f"[경고] {file_path} 로드 실패: {e}")
    else:
        print(f"[경고] 파일 없음: {file_path}")

with open(final_output_path, "wb") as f:
    pickle.dump(merged_progress, f)

print(f"[INFO] 병합 완료. 총 청크 수: {len(merged_progress)}")
# Out:
# [INFO] 병합 완료. 총 청크 수: 116218
